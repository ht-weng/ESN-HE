# %%
import pandas as pd
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv('lorenz_ode_data.txt', sep='\s+', names=['Time', 'X', 'Y', 'Z'])
df
# Out:
#        Time        X         Y          Z
# 0      0.00  8.00000  0.000000   0.000000
# 1      0.01  7.34334  2.128690   0.080851
# 2      0.02  6.94263  4.079390   0.297407
# 3      0.03  6.75953  5.912040   0.626982
# 4      0.04  6.76461  7.676910   1.063400
# ...     ...      ...       ...        ...
# 3996  39.96 -2.53716  0.494512  25.609800
# 3997  39.97 -2.25197  0.424676  24.925000
# 3998  39.98 -2.00090  0.348554  24.261000
# 3999  39.99 -1.78115  0.268857  23.616800
# 4000  40.00 -1.58999  0.187603  22.991600
#
# [4001 rows x 4 columns]

# %%
fig = plt.figure(figsize=(20,10))
ax = fig.add_subplot(111, projection='3d')
ax.plot(df['X'], df['Y'], df['Z'])
ax.set_xlabel('X axis')
ax.set_ylabel('Y axis')
ax.set_zlabel('Z axis')
plt.show()
